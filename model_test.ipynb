# %%
from model import book_recommendations
import numpy as np
import pandas as pd
# Out:
# c:\Users\kjeet\OneDrive\Documents\GitHub\learning-model\model.py:10: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_data = pd.read_csv("data/Books.csv")

# %%
book_recommendations(50)
# Out:
#                                            Book-Title     Rating        ISBN
# 0   The Shelters of Stone (Earth's Children Series...  10.000000  0195153448
# 1                                    The Great Gatsby  10.000000  0002005018
# 2                             The Secret Life of Bees   9.971946  0060973129
# 3                               The Other Boleyn Girl   9.742171  0374157065
# 4                                                Free   9.542398  0393045218
# 5                                      The Bean Trees   9.427606  0399135782
# 6                                         Desperation   9.214615  0425176428
# 7                                              Carrie   9.013358  0671870432
# 8   Angry Housewives Eating Bon Bons (Ballantine R...   8.967784  0679425608
# 9                                                Cujo   8.961384  074322678X
# 10                                         Lost Light   8.907393  0771074670
# ...
